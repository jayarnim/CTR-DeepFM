# %%
MODEL_CLS = "deepfm"
DATASET = "criteo"
EMBEDDING_DIM = 32
PATH_WORK_DIR = "../.."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PAPER REVIEW\CTR\CTR-DeepFM

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Packages

# %%
import pandas as pd
from ctr import config, featuremap, datamodule, trainer, evaluator, utils
import deepfm

# %%
PATH = f"./config/{DATASET}/{MODEL_CLS}.yaml"
cfg = config.build_config(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Load Data

# %%
PATH = f"./data/{DATASET}.csv"
df = pd.read_csv(PATH)

# %%
y_col = "label"
X_col = df.columns.difference([y_col])

# %%
NUMERIC_COL = [
    col 
    for col in X_col 
    if "I" in col
]

CATEGORICAL_COL = [
    col 
    for col in X_col 
    if "C" in col
]

# %%
y = df[y_col]
X = df[X_col]

# %% [markdown]
# # Data Preparation

# %%
kwargs = dict(
    X=X,
    y=y,
    cfg=cfg.datamodule,
    scaling=NUMERIC_COL,
)

dataloaders = datamodule.build_datamodule(**kwargs)

# %%
kwargs = dict(
    X=X,
    cat_cols=CATEGORICAL_COL,
    num_cols=NUMERIC_COL,
)

feature_map = featuremap.build_feature_map(**kwargs)

# %% [markdown]
# # Modeling

# %%
NUM_FEATURES = 39

i = 0
units = list()

while True:
    UNIT = (2**i)
    if EMBEDDING_DIM*NUM_FEATURES < UNIT:
        break
    else:
        units.append(UNIT)
        i+=1

HIDDEN_DIM = units[:-4:-1]

# %%
kwargs = dict(
    **cfg.model.params,
    embedding_dim=EMBEDDING_DIM,
    hidden_dim=HIDDEN_DIM,
    feature_map=feature_map,
)

model = deepfm.model.DeepFactorizationMachine(**kwargs)

# %% [markdown]
# # Training

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build_trainer(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 1
# BEST SCORE: 0.7732

# %%
SUPTITLE = "DeepFM Training History"
TRN_SCORE = "BCE"
VAL_SCORE = "AUROC"
FIGSIZE = (7,3)

kwargs = dict(
    records=records,
    suptitle=SUPTITLE,
    trn=TRN_SCORE,
    val=VAL_SCORE,
    figsize=FIGSIZE,
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Evaluation

# %%
kwargs = dict(
    model=model, 
    threshold=records["threshold"],
)

msr = evaluator.build_evaluator(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 196/196 [00:01<00:00, 100.21it/s]

# %%
metrics_sheet
# Out:
#    threshold  accuracy  precision    recall        f1     auroc   logloss
# 0   0.276279   0.70049   0.446746  0.708596  0.547998  0.773866  0.474303

# %% [markdown]
# # Save

# %%
PATH = f'./checkpoints/{DATASET}/{MODEL_CLS}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
